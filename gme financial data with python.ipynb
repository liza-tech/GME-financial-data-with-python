# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
! pip install yfinance

# %%
import yfinance as yf

# %%
gme= yf.Ticker('GME')

# %%
gme.info
# Out:
# {'zip': '76051',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 12000,
# ...

# %%
 hist= gme.history(period="max")

# %%
hist
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2002-02-13    6.480513    6.773399    6.413183    6.766666  19054000
# 2002-02-14    6.850831    6.864296    6.682506    6.733003   2755400
# 2002-02-15    6.733001    6.749833    6.632006    6.699336   2097400
# 2002-02-19    6.665671    6.665671    6.312189    6.430017   1852600
# 2002-02-20    6.463681    6.648838    6.413183    6.648838   1723200
# ...                ...         ...         ...         ...       ...
# 2021-09-02  213.860001  214.800003  206.300003  213.520004   1852000
# 2021-09-03  212.050003  216.270004  198.839996  202.750000   2658600
# 2021-09-07  206.250000  209.899994  196.100006  199.000000   2496300
# 2021-09-08  201.860001  206.880005  190.679993  198.800003   5173600
# 2021-09-10  198.408005  202.000000  190.000000  192.750107   1985982
#
#             Dividends  Stock Splits
# Date
# 2002-02-13        0.0           0.0
# 2002-02-14        0.0           0.0
# ...

# %%
gme.actions  #dividends or stocks splits
# Out:
#             Dividends  Stock Splits
# Date
# 2007-03-19      0.000           2.0
# 2012-02-16      0.150           0.0
# 2012-05-24      0.150           0.0
# 2012-08-24      0.250           0.0
# 2012-11-26      0.250           0.0
# 2013-03-01      0.275           0.0
# 2013-05-31      0.275           0.0
# 2013-08-29      0.275           0.0
# 2013-12-02      0.275           0.0
# 2014-03-13      0.330           0.0
# 2014-06-02      0.330           0.0
# 2014-08-29      0.330           0.0
# 2014-11-21      0.330           0.0
# 2015-03-13      0.360           0.0
# 2015-06-08      0.360           0.0
# 2015-09-04      0.360           0.0
# 2015-12-01      0.360           0.0
# 2016-03-04      0.370           0.0
# 2016-06-06      0.370           0.0
# 2016-09-07      0.370           0.0
# 2016-11-29      0.370           0.0
# 2017-03-10      0.380           0.0
# 2017-06-05      0.380           0.0
# 2017-09-07      0.380           0.0
# 2017-11-30      0.380           0.0
# ...

# %%
gme.dividends
# Out:
# Date
# 2012-02-16    0.150
# 2012-05-24    0.150
# 2012-08-24    0.250
# 2012-11-26    0.250
# 2013-03-01    0.275
# 2013-05-31    0.275
# 2013-08-29    0.275
# 2013-12-02    0.275
# 2014-03-13    0.330
# 2014-06-02    0.330
# 2014-08-29    0.330
# 2014-11-21    0.330
# 2015-03-13    0.360
# 2015-06-08    0.360
# 2015-09-04    0.360
# 2015-12-01    0.360
# 2016-03-04    0.370
# 2016-06-06    0.370
# 2016-09-07    0.370
# 2016-11-29    0.370
# 2017-03-10    0.380
# 2017-06-05    0.380
# 2017-09-07    0.380
# 2017-11-30    0.380
# 2018-03-02    0.380
# 2018-06-11    0.380
# 2018-09-17    0.380
# 2018-12-10    0.380
# 2019-03-14    0.380
# Name: Dividends, dtype: float64

# %%
gme.splits
# Out:
# Date
# 2007-03-19    2.0
# Name: Stock Splits, dtype: float64

# %%
gme.financials
# Out:
#                                         2021-01-30  2020-02-01  2019-02-02  \
# Research Development                          None        None        None
# Effect Of Accounting Charges                  None        None        None
# Income Before Tax                       -2.699e+08  -4.268e+08  -7.531e+08
# Minority Interest                             None        None        None
# Net Income                              -2.153e+08  -4.709e+08   -6.73e+08
# Selling General Administrative          1.5088e+09  1.8474e+09  1.9876e+09
# Gross Profit                            1.2595e+09  1.9087e+09  2.3081e+09
# Ebit                                    -2.493e+08    6.13e+07   3.205e+08
# Operating Income                        -2.493e+08    6.13e+07   3.205e+08
# Other Operating Expenses                      None        None        None
# Interest Expense                          -3.4e+07   -3.85e+07   -5.68e+07
# ...

# %%
gme.quarterly_financials
# Out:
#                                         2021-07-31  2021-05-01  2021-01-30  \
# Research Development                          None        None        None
# Effect Of Accounting Charges                  None        None        None
# Income Before Tax                        -1.17e+08   -6.55e+07    1.06e+07
# Minority Interest                             None        None        None
# Net Income                              -1.232e+08   -6.68e+07    8.05e+07
# Selling General Administrative           7.578e+08    3.71e+08   4.136e+08
# Gross Profit                             6.418e+08   3.301e+08   4.486e+08
# Ebit                                     -1.16e+08   -4.09e+07     3.5e+07
# Operating Income                         -1.16e+08   -4.09e+07     3.5e+07
# Other Operating Expenses                      None        None        None
# Interest Expense                          -1.2e+06   -2.48e+07    -8.5e+06
# ...

# %%
gme.major_holders
# Out:
#         0                                      1
# 0  18.98%        % of Shares Held by All Insider
# 1  37.08%       % of Shares Held by Institutions
# 2  45.77%        % of Float Held by Institutions
# 3     346  Number of Institutions Holding Shares

# %%
gme.institutional_holders
# Out:
#                                        Holder   Shares Date Reported   % Out  \
# 0                              Blackrock Inc.  7159418    2021-06-29  0.0997
# 1                  Vanguard Group, Inc. (The)  6041749    2021-06-29  0.0841
# 2                    State Street Corporation  1606900    2021-06-29  0.0224
# 3               Geode Capital Management, LLC   674532    2021-06-29  0.0094
# 4  Charles Schwab Investment Management, Inc.   672727    2021-06-29  0.0094
# 5               Renaissance Technologies, LLC   606141    2021-06-29  0.0084
# 6         Bank Of New York Mellon Corporation   498333    2021-06-29  0.0069
# 7                              Morgan Stanley   493850    2021-06-29  0.0069
# 8             Principal Financial Group, Inc.   390578    2021-06-29  0.0054
# 9                  Northern Trust Corporation   368090    2021-06-29  0.0051
#
#         Value
# 0  1533117770
# 1  1293780130
# 2   344101566
# 3   144444282
# 4   144057759
# 5   129799033
# ...

# %%
gme.cashflow
# Out:
#                                             2021-01-30    2020-02-01  \
# Change To Liabilities                      -78600000.0 -7.928000e+08
# Total Cashflows From Investing Activities   36900000.0 -6.090000e+07
# Net Borrowings                             -58200000.0 -4.045000e+08
# Total Cash From Financing Activities       -55400000.0 -6.447000e+08
# Change To Operating Activities              24400000.0  7.700000e+06
# Issuance Of Stock                            3100000.0  3.100000e+06
# Net Income                                -215300000.0 -4.709000e+08
# Change In Cash                             121500000.0 -1.127000e+09
# Effect Of Exchange Rate                     16300000.0 -6.900000e+06
# Total Cash From Operating Activities       123700000.0 -4.145000e+08
# Depreciation                                80700000.0  9.620000e+07
# Other Cashflows From Investing Activities    1400000.0  1.240000e+07
# Dividends Paid                               -300000.0 -4.050000e+07
# ...

# %%
gme.earnings
# Out:
#          Revenue   Earnings
# Year
# 2018  8547100000   34700000
# 2019  8285300000 -673000000
# 2020  6466000000 -470900000
# 2021  5089800000 -215300000

# %%
gme.sustainability

# %%
gme.recommendations
# Out:
#                                       Firm        To Grade From Grade Action
# Date
# 2012-08-17 10:52:00     Ascendiant Capital             Buy              main
# 2012-09-04 05:41:00          Goldman Sachs             Buy    Neutral     up
# 2012-09-05 10:10:00      National Alliance  Market Perform              main
# 2012-09-13 15:46:00           PiperJaffray         Neutral              main
# 2012-10-09 16:19:00           PiperJaffray         Neutral              main
# ...                                    ...             ...        ...    ...
# 2021-01-27 13:56:33      B of A Securities    Underperform              main
# 2021-03-24 10:49:55  Telsey Advisory Group    Underperform              main
# 2021-03-24 13:21:24                Wedbush    Underperform    Neutral   down
# 2021-04-12 11:31:19     Ascendiant Capital            Sell       Hold   down
# 2021-06-10 12:35:31                Wedbush    Underperform              main
#
# [83 rows x 4 columns]

# %%
gme.recommendations ['To Grade'].value_counts()
# Out:
# Neutral           23
# Buy               17
# Outperform        14
# Underperform      13
# Sell               5
# Hold               4
# Market Perform     3
# Perform            2
# Sector Weight      1
# Overweight         1
# Name: To Grade, dtype: int64

# %%
gme.calendar
# Out:
#                                     0                    1
# Earnings Date     2021-12-06 10:59:00  2021-12-10 12:00:00
# Earnings Average                -0.51                -0.51
# Earnings Low                    -0.87                -0.87
# Earnings High                   -0.04                -0.04
# Revenue Average            1176970000           1176970000
# Revenue Low                 966000000            966000000
# Revenue High               1306000000           1306000000

# %%
gme.isin  # international code of compant GME
# Out:
# 'US36467W1099'

# %%
gme.options
# Out:
# ('2021-09-10',
#  '2021-09-17',
#  '2021-09-24',
#  '2021-10-01',
#  '2021-10-08',
#  '2021-10-15',
#  '2021-10-22',
#  '2021-11-19',
#  '2021-12-17',
#  '2022-01-21',
#  '2022-04-14',
#  '2022-06-17',
#  '2023-01-20')

# %%
hist.plot(kind='line',figsize=(12,6))

# %%
hist.plot(kind='line',figsize=(12,6),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F9228291C8>,
# ...
#       dtype=object)

# %%
major_indices= pd.read_html("file:///C:/Users/Liza/Downloads/world-indices.html")[0]

# %%
major_indices.head()
# Out:
#   Symbol                       Name  Last Price  Change % Change    Volume  \
# 0  ^GSPC                    S&P 500     4526.21   -9.22   -0.20%    1.219B
# 1   ^DJI                     Dow 30    35148.04 -221.05   -0.62%  213.062M
# 2  ^IXIC                     Nasdaq    15393.58   30.07   +0.20%    2.842B
# 3   ^NYA        NYSE COMPOSITE (DJ)    16833.21  -76.51   -0.45%         0
# 4   ^XAX  NYSE AMEX COMPOSITE INDEX     3055.38  -31.99   -1.04%         0
#
#    Intraday High/Low  52 Week Range  Day Chart
# 0                NaN            NaN        NaN
# 1                NaN            NaN        NaN
# 2                NaN            NaN        NaN
# 3                NaN            NaN        NaN
# 4                NaN            NaN        NaN

# %%
major_indices['Symbol']
# Out:
# 0         ^GSPC
# 1          ^DJI
# 2         ^IXIC
# 3          ^NYA
# 4          ^XAX
# 5      ^BUK100P
# 6          ^RUT
# 7          ^VIX
# 8         ^FTSE
# 9        ^GDAXI
# 10        ^FCHI
# 11    ^STOXX50E
# 12        ^N100
# 13         ^BFX
# 14     IMOEX.ME
# 15        ^N225
# 16         ^HSI
# 17    000001.SS
# 18    399001.SZ
# 19         ^STI
# 20        ^AXJO
# 21        ^AORD
# 22       ^BSESN
# 23        ^JKSE
# 24        ^KLSE
# 25        ^NZ50
# 26        ^KS11
# 27        ^TWII
# 28      ^GSPTSE
# 29        ^BVSP
# 30         ^MXX
# 31        ^IPSA
# 32        ^MERV
# 33    ^TA125.TA
# 34      ^CASE30
# 35     ^JN0U.JO
# Name: Symbol, dtype: object

# %%
ticker_list=major_indices['Symbol'].str.replace("^"," ").str.lower().to_list()

# %%
yf.Tickers(ticker_list)
# Out:
# yfinance.Tickers object < GSPC, DJI, IXIC, NYA, XAX, BUK100P, RUT, VIX, FTSE, GDAXI, FCHI, STOXX50E, N100, BFX,IMOEX.ME, N225, HSI,000001.SS,399001.SZ, STI, AXJO, AORD, BSESN, JKSE, KLSE, NZ50, KS11, TWII, GSPTSE, BVSP, MXX, IPSA, MERV, TA125.TA, CASE30, JN0U.JO>

# %%
tickerData=yf.Tickers(ticker_list)

# %%
df=yf.download(ticker_list, period='id',start="2021-01-01",end="2021-09-08")
# Out:
# [*********************100%***********************]  36 of 36 completed
#
# 33 Failed downloads:
# -  HSI: No data found, symbol may be delisted
# -  FTSE: No data found, symbol may be delisted
# -  STI: No data found, symbol may be delisted
# -  TWII: No data found, symbol may be delisted
# -  RUT: No data found, symbol may be delisted
# -  N100: No data found, symbol may be delisted
# -  NZ50: No data found, symbol may be delisted
# -  XAX: No data found, symbol may be delisted
# -  AORD: No data found, symbol may be delisted
# -  BVSP: No data found, symbol may be delisted
# -  IPSA: No data found, symbol may be delisted
# -  KS11: No data found, symbol may be delisted
# -  IXIC: No data found, symbol may be delisted
# -  CASE30: No data found, symbol may be delisted
# -  N225: No data found, symbol may be delisted
# -  STOXX50E: No data found, symbol may be delisted
# -  BSESN: No data found, symbol may be delisted
# -  NYA: No data found, symbol may be delisted
# ...

# %%
len(ticker_list)
# Out:
# 36

# %%
df.columns
# Out:
# MultiIndex([('Adj Close',     ' AORD'),
#             ('Adj Close',     ' AXJO'),
#             ('Adj Close',      ' BFX'),
#             ('Adj Close',    ' BSESN'),
#             ('Adj Close',  ' BUK100P'),
#             ('Adj Close',     ' BVSP'),
#             ('Adj Close',   ' CASE30'),
#             ('Adj Close',      ' DJI'),
#             ('Adj Close',     ' FCHI'),
#             ('Adj Close',     ' FTSE'),
#             ...
#             (   'Volume',      ' RUT'),
#             (   'Volume',      ' STI'),
#             (   'Volume', ' STOXX50E'),
#             (   'Volume', ' TA125.TA'),
#             (   'Volume',     ' TWII'),
#             (   'Volume',      ' VIX'),
#             (   'Volume',      ' XAX'),
#             (   'Volume', '000001.SS'),
#             (   'Volume', '399001.SZ'),
#             (   'Volume',  'IMOEX.ME')],
#            length=216)

# %%
df.head()
# Out:
#                     Adj Close                                                \
#                          AORD  AXJO  BFX  BSESN  BUK100P  BVSP  CASE30  DJI
# Date
# 2021-01-04 00:00:00       NaN   NaN  NaN    NaN      NaN   NaN     NaN  NaN
# 2021-01-05 00:00:00       NaN   NaN  NaN    NaN      NaN   NaN     NaN  NaN
# 2021-01-06 00:00:00       NaN   NaN  NaN    NaN      NaN   NaN     NaN  NaN
# 2021-01-07 00:00:00       NaN   NaN  NaN    NaN      NaN   NaN     NaN  NaN
# 2021-01-08 00:00:00       NaN   NaN  NaN    NaN      NaN   NaN     NaN  NaN
#
#                                  ... Volume                                 \
#                      FCHI  FTSE  ...    RUT  STI  STOXX50E  TA125.TA  TWII
# Date                             ...
# 2021-01-04 00:00:00   NaN   NaN  ...    NaN  NaN       NaN       NaN   NaN
# 2021-01-05 00:00:00   NaN   NaN  ...    NaN  NaN       NaN       NaN   NaN
# 2021-01-06 00:00:00   NaN   NaN  ...    NaN  NaN       NaN       NaN   NaN
# ...

# %%
adj_close=df.dropna(thresh=10,axis=1)['Adj Close']

# %%
adj_close.head()
# Out:
#                        000001.SS     399001.SZ     IMOEX.ME
# Date
# 2021-01-04 00:00:00  3502.958008  14827.469727  3350.510010
# 2021-01-05 00:00:00  3528.677002  15147.570312  3359.149902
# 2021-01-06 00:00:00  3550.876953  15187.610352  3371.030029
# 2021-01-07 00:00:00  3576.205078  15356.400391          NaN
# 2021-01-08 00:00:00  3570.110107  15319.290039  3454.820068

# %%
adj_close.describe().T
# Out:
#            count          mean         std           min           25%  \
# 000001.SS  167.0   3516.052888   71.350164   3357.739990   3463.679077
# 399001.SZ  167.0  14611.554103  558.274332  13407.349609  14210.020020
# IMOEX.ME   172.0   3645.392328  190.432856   3277.080078   3477.854980
#
#                     50%           75%           max
# 000001.SS   3518.760010   3569.769531   3696.167969
# 399001.SZ  14697.500000  15005.645020  15962.250000
# IMOEX.ME    3638.605103   3822.659912   4028.250000

# %%
adj_close.plot(figsize=(12,12),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F924129F08>,
# ...
#       dtype=object)
